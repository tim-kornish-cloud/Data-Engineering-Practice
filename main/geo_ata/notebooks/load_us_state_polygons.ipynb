# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import shapefile
import time

# %%
class Reader:
    def __init__(self):
        self.shapefile = None
        self.indexes = None
        self.df_features = None
        self.projections = None

    def read_shapefile(self, shapefile="./vector_input/mtbs_fod_pts_data/mtbs_FODpoints_DD.shp",
                       indexes=None,
                       db_features=None):
        """
        All 3 inputs below result in the same dataframe. when geopandas reads a single file,
        it will also read the relevant adjacent files with same file name and different extensions.
        """
        self.shapefile = gpd.read_file(shapefile)
        if(indexes != None):
            self.indexes = gpd.read_file(indexes)
        if(db_features != None):
            self.db_features = pd.DataFrame(gpd.read_file(db_features))

    def output_shapefile(self, print_head=False, print_columns=False, print_extra_variables=False, close_window_after_sleep=True, plot_file=True):
        if(print_head):
            print(self.shapefile.head())
        if(print_columns):
            print(self.shapefile.columns)
        """
        ['Event_ID', 'irwinID', 'Incid_Name', 'Incid_Type', 'Map_ID', 'Map_Prog',
       'Asmnt_Type', 'BurnBndAc', 'BurnBndLat', 'BurnBndLon', 'Ig_Date',
       'Pre_ID', 'Post_ID', 'Perim_ID', 'dNBR_offst', 'dNBR_stdDv', 'NoData_T',
       'IncGreen_T', 'Low_T', 'Mod_T', 'High_T', 'Comment', 'ORIG_FID',
       'geometry']
        """
        if(print_extra_variables):
            print(self.indexes.head())
            print(self.indexes.columns)
            print(self.db_features.head())
            print(self.db_features.columns)
        """
        ['Event_ID', 'irwinID', 'Incid_Name', 'Incid_Type', 'Map_ID', 'Map_Prog',
       'Asmnt_Type', 'BurnBndAc', 'BurnBndLat', 'BurnBndLon', 'Ig_Date',
       'Pre_ID', 'Post_ID', 'Perim_ID', 'dNBR_offst', 'dNBR_stdDv', 'NoData_T',
       'IncGreen_T', 'Low_T', 'Mod_T', 'High_T', 'Comment', 'ORIG_FID',
       'geometry']
        """
        #print(self.projections)
        self.shapefile.plot()
        if(plot_file):
            plt.show()
            if (close_window_after_sleep):
                time.sleep(5)
                plt.close()

    def inspect_polygons(self):
        for row in self.shapefile['geometry']:
            print(row)
            """
            has list of polygons and multipolygons
            """

    def plot_polygon(self, polygons_to_plot=1):
        for index, row in self.shapefile.iterrows():
            #for col in self.shapefile.columns:
            #print(col + ": " + str(self.shapefile.iloc[index][col]) + "\n")
            print("about to plot")
            poly = gpd.GeoSeries(row.geometry)
            print(poly)
            poly.plot()
            print("plotted")
            plt.show()
            time.sleep(5)
            plt.close()

# %%
states = Reader()

# %%
states.read_shapefile(".//vector_input/US_States/cb_2018_us_state_500k/cb_2018_us_state_500k.shp", None, None)

# %%
states.output_shapefile(False, False, False, False, False)

# %%
states.plot_polygon()
# Out:
# about to plot
# 0    MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-103.00257 36.52659, -103.00219 36.6...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-82.64320 38.16909, -82.64300 38.169...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-88.86770 29.86155, -88.86566 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-83.19159 42.03537, -83.18993 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-70.23405 41.28565, -70.22361 ...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-117.24267 44.39655, -117.23484 44.3...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-80.17628 25.52505, -80.17395 ...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-104.05342 41.17054, -104.05324 41.1...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-122.57039 48.53785, -122.5686...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-109.05017 31.48000, -109.04984 31.4...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-65.23805 18.32167, -65.23467 ...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-104.05788 44.99761, -104.05078 44.9...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-94.71830 29.72885, -94.71721 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-118.60442 33.47855, -118.5987...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-88.05338 30.50699, -88.05109 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-81.27939 31.30792, -81.27716 ...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-80.51989 40.90666, -80.51909 40.921...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-95.77355 40.57820, -95.76853 40.583...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-109.06025 38.59933, -109.05954 38.7...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-114.05296 37.59278, -114.05247 37.6...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-90.31030 35.00429, -90.30988 35.009...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-111.05456 45.00095, -111.04507 45.0...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-72.03683 41.24984, -72.03496 ...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-102.05174 40.00308, -101.91670 40.0...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((179.48246 51.98283, 179.48656 ...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-120.00574 39.22866, -120.00559 39.2...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-91.51297 40.18106, -91.51107 40.188...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-73.43774 44.04501, -73.43199 44.063...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-116.04914 48.50205, -116.04913 48.5...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-96.63970 42.73707, -96.63589 42.741...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-79.50795 33.02008, -79.50713 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-70.61702 42.97718, -70.61529 ...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-114.81629 32.50804, -114.81432 32.5...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-77.11976 38.93434, -77.11253 38.940...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-168.14582 -14.54791, -168.145...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-64.62799 17.78933, -64.62717 ...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-75.55910 39.62906, -75.55945 39.629...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-76.05015 37.98691, -76.04998 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-67.35580 44.64226, -67.35437 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-156.06076 19.73055, -156.0566...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-75.56555 39.51485, -75.56174 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((144.64538 13.23627, 144.64716 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((146.05103 16.00674, 146.05167 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-71.28802 41.64558, -71.28647 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-89.40565 36.52817, -89.39869 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-82.73571 41.60336, -82.73392 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-86.95617 45.35549, -86.95463 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-123.59892 46.25145, -123.5984...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-104.04868 48.86378, -104.04865 48.8...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-94.61783 36.49941, -94.61765 36.499...
# dtype: geometry
# plotted
# about to plot
# 0    POLYGON ((-88.09776 37.90403, -88.09448 37.905...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-89.59206 47.96668, -89.59147 ...
# dtype: geometry
# plotted
# about to plot
# 0    MULTIPOLYGON (((-72.76143 41.24233, -72.75973 ...
# dtype: geometry
# plotted

# %%
states
